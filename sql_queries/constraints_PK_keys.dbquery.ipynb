-- %%
ALTER TABLE gold.dim_coin
ALTER COLUMN coin_id SET NOT NULL;

ALTER TABLE gold.dim_coin
ADD CONSTRAINT pk_dim_coin PRIMARY KEY (coin_id);

ALTER TABLE gold.dim_date
ALTER COLUMN date SET NOT NULL;

ALTER TABLE gold.dim_date
ADD CONSTRAINT pk_dim_date PRIMARY KEY (date);
